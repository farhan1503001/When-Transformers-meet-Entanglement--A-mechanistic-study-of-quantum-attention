# %% [markdown]
# # Quantum Attention — TREC-6 (Question-Type Classification, 6 classes)
#
# Single-head and multi-head **quantum-scored attention** vs classical dot-product
# attention, with a separability-grounded **entanglement ablation**
# (`none / intra / cross / full`), on **TREC**.
#
# This notebook runs four experiments and **checkpoints every result to Google Drive**
# after each (condition, seed) run, so it survives Colab disconnects — just re-run the
# cell and it resumes where it stopped.
#
# **Experiments**
# 1. **A — Architecture ablation (4 heads):** quantum head as 1 of 4; the realistic setting.
# 2. **B — Single-head ablation:** quantum head is the *only* attention → tests whether
#    entanglement matters once *undiluted*.
# 3. **C — Data-efficiency:** accuracy vs training size (the low-data regime where quantum
#    methods are most defensible).
# 4. **D — Qubit width / encoding bottleneck:** 2 vs 4 vs 8 qubits (1/2/4 angles per side)
#    → tests whether a wider encoding lets entanglement matter.
#
# **Run order:** Setup → Download → Core → Config → Harness → run any Experiment cell(s)
# → Reporting. Recommended: **A and B first** (fast, answer the core question), then C and D.

# %% [markdown]
# ## 1 · Setup (install, mount Drive, choose device)

# %%
pip -q install -U pennylane

# %%
# PennyLane is the quantum simulator; torch ships with Colab.
#!pip -q install -U pennylane
import os, json, time, math, itertools
import torch
print("torch", torch.__version__)
import pennylane as qml
print("pennylane", qml.__version__)

# Mount Google Drive for checkpointing.
from google.colab import drive
drive.mount('/content/drive')

DATASET = 'trec'
DRIVE_ROOT = '/content/drive/MyDrive/quantum_attention'
RESULTS_DIR = os.path.join(DRIVE_ROOT, DATASET)
FIG_DIR = os.path.join(RESULTS_DIR, 'figures')
os.makedirs(RESULTS_DIR, exist_ok=True); os.makedirs(FIG_DIR, exist_ok=True)
print("Results ->", RESULTS_DIR)

# The 4-qubit statevector sim is CPU-bound; GPU does not accelerate default.qubit.
# CPU is the right choice and avoids device-mismatch. (High-RAM runtime helps memory.)
DEVICE = 'cpu'
print("device =", DEVICE)
# Out:
# torch 2.11.0+cpu
# pennylane 0.45.0
# Mounted at /content/drive
# Results -> /content/drive/MyDrive/quantum_attention/trec
# device = cpu

# %% [markdown]
# ## 2 · Download data (cached on the Colab VM)

# %%
import urllib.request
def download(url, path):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    if os.path.exists(path) and os.path.getsize(path) > 0:
        print("exists:", path); return
    urllib.request.urlretrieve(url, path)
    print("downloaded:", path, os.path.getsize(path), "bytes")

download("https://raw.githubusercontent.com/honnibal/dsr16_nlp/master/data/question_classification/train_5500.label", "trec/train.label")
download("https://raw.githubusercontent.com/justindomingue/nlp/master/question_classification/data/TREC_10.label", "trec/test.label")
# Out:
# downloaded: trec/train.label 335858 bytes
# downloaded: trec/test.label 23354 bytes

# %% [markdown]
# ## 3 · Core code (model + utilities)
# Generalized quantum attention head (configurable qubit count), the small Transformer, data utilities, val-based training, and the permutation test.

# %%
"""
qatt_core.py — Consolidated core for the Quantum Attention experiments.
Embedded verbatim into each Colab notebook. Generalized to support a
configurable number of qubits (even; half encode the query, half the key).

Contents:
  * QuantumAttentionHead / MixedMultiHeadAttention / TransformerBlock / TextTransformer
  * attention_entropy
  * tokenize / build_vocab / batchify
  * run_one (val-based model selection) + permutation_test + mean_std
The dataset loaders live in the notebook (they differ per dataset).
"""

import math, time, itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import pennylane as qml

PAD, UNK = 0, 1


# =========================================================================== #
# Quantum scoring circuit (generalized to n_qubits, half query / half key)
# =========================================================================== #
def build_quantum_score_qnode(n_qubits=4, entangle="full"):
    """Wires 0..h-1 carry query angles, wires h..2h-1 carry key angles (h=n_qubits/2).
    weights shape (2, n_qubits, 3): rotation layer 0 (pre-entangler) + layer 1 (post).
    The post-entangler rotation layer is REQUIRED so CZ gates (diagonal in Z) become
    visible to the Z-basis readout; without it entanglement has zero effect.

    entangle:
      none  -> no CZ                          (score separable: <Z_q0 Z_k0>=<Z_q0><Z_k0>)
      intra -> CZ within query / within key   (still separable for this readout)
      cross -> CZ pairing q_i with k_i         (genuine query<->key entanglement)
      full  -> cross + intra
    """
    assert n_qubits % 2 == 0 and n_qubits >= 2
    h = n_qubits // 2
    q_wires = list(range(h))
    k_wires = list(range(h, n_qubits))
    cross = [(q_wires[i], k_wires[i]) for i in range(h)]
    intra = ([(q_wires[i], q_wires[i + 1]) for i in range(h - 1)]
             + [(k_wires[i], k_wires[i + 1]) for i in range(h - 1)])
    cz_pairs = {"none": [], "intra": intra,
                "cross": cross, "full": cross + intra}[entangle]
    dev = qml.device("default.qubit", wires=n_qubits)

    @qml.qnode(dev, interface="torch", diff_method="backprop")
    def circuit(inputs, weights):
        qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation="Y")
        for w in range(n_qubits):
            qml.RX(weights[0, w, 0], wires=w)
            qml.RY(weights[0, w, 1], wires=w)
            qml.RZ(weights[0, w, 2], wires=w)
        for a, b in cz_pairs:
            qml.CZ(wires=[a, b])
        for w in range(n_qubits):
            qml.RX(weights[1, w, 0], wires=w)
            qml.RY(weights[1, w, 1], wires=w)
            qml.RZ(weights[1, w, 2], wires=w)
        return qml.expval(qml.PauliZ(q_wires[0]) @ qml.PauliZ(k_wires[0]))

    return circuit


class QuantumAttentionHead(nn.Module):
    def __init__(self, head_dim, n_qubits=4, entangle="full", chunk=8192):
        super().__init__()
        assert n_qubits % 2 == 0
        self.n_qubits = n_qubits
        self.h = n_qubits // 2                       # angles encoded per side
        self.entangle = entangle
        self.chunk = chunk                           # max pairs per circuit call
        self.q_proj = nn.Linear(head_dim, self.h)
        self.k_proj = nn.Linear(head_dim, self.h)
        self.qweights = nn.Parameter(0.1 * torch.randn(2, n_qubits, 3))
        self.scale = nn.Parameter(torch.tensor(4.0))
        self.circuit = build_quantum_score_qnode(n_qubits, entangle)

    def _run_circuit(self, flat, qw):
        # Evaluate in chunks so peak memory stays bounded (matters at n_qubits>=6,
        # where the statevector is 2^n_qubits per pair). Each chunk is autograd-
        # connected, so gradients still flow and accumulate into qw.
        n = flat.shape[0]
        if n <= self.chunk:
            return self.circuit(flat, qw)
        outs = [self.circuit(flat[i:i + self.chunk], qw)
                for i in range(0, n, self.chunk)]
        return torch.cat(outs, dim=0)

    def forward(self, q, k, v, key_mask=None, debug=False):
        B, L, D = q.shape
        qa = torch.tanh(self.q_proj(q)) * math.pi     # (B,L,h)
        ka = torch.tanh(self.k_proj(k)) * math.pi
        qa_exp = qa.unsqueeze(2).expand(B, L, L, self.h)
        ka_exp = ka.unsqueeze(1).expand(B, L, L, self.h)
        pairs = torch.cat([qa_exp, ka_exp], dim=-1)   # (B,L,L,n_qubits)
        flat = pairs.reshape(-1, self.n_qubits).float()
        # default.qubit simulates on CPU; run there and move scalars back.
        scores = self._run_circuit(flat.cpu(), self.qweights.cpu())
        scores = scores.reshape(B, L, L).to(device=v.device, dtype=v.dtype)
        if debug:
            with torch.no_grad():
                print(f"[qhead] score range [{scores.min():.3f},{scores.max():.3f}] "
                      f"std={scores.std():.3f}")
        scores = scores * self.scale
        if key_mask is not None:
            scores = scores.masked_fill(key_mask == 0, float("-inf"))
        attn = F.softmax(scores, dim=-1)
        out = torch.matmul(attn, v)
        return out, attn

    def self_test(self, device="cpu"):
        x = torch.randn(2, 3, self.q_proj.in_features, device=device)
        self.to(device)
        out, attn = self.forward(x, x, x, debug=True)
        out.sum().backward()
        g = self.qweights.grad
        gn = None if g is None else g.norm().item()
        ok = gn and gn > 1e-8
        print(f"[self_test] nq={self.n_qubits} grad_norm={gn} "
              f"{'OK' if ok else 'DEAD GRADIENT'}")
        self.zero_grad()
        return ok


class MixedMultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads, use_quantum=True, entangle="full", n_qubits=4):
        super().__init__()
        assert d_model % n_heads == 0
        self.d_model, self.n_heads = d_model, n_heads
        self.head_dim = d_model // n_heads
        self.use_quantum = use_quantum
        self.q_lin = nn.Linear(d_model, d_model)
        self.k_lin = nn.Linear(d_model, d_model)
        self.v_lin = nn.Linear(d_model, d_model)
        self.out_lin = nn.Linear(d_model, d_model)
        if use_quantum:
            self.qhead = QuantumAttentionHead(self.head_dim, n_qubits, entangle)

    def forward(self, x, key_mask=None, return_attn=False, debug=False):
        B, L, _ = x.shape
        H, Dh = self.n_heads, self.head_dim
        q = self.q_lin(x).view(B, L, H, Dh).transpose(1, 2)
        k = self.k_lin(x).view(B, L, H, Dh).transpose(1, 2)
        v = self.v_lin(x).view(B, L, H, Dh).transpose(1, 2)
        outs, attns = [], {}
        for hh in range(H):
            if self.use_quantum and hh == 0:
                o, a = self.qhead(q[:, hh], k[:, hh], v[:, hh],
                                  key_mask=key_mask, debug=debug)
                attns["quantum"] = a
            else:
                sc = torch.matmul(q[:, hh], k[:, hh].transpose(-2, -1)) / math.sqrt(Dh)
                if key_mask is not None:
                    sc = sc.masked_fill(key_mask == 0, float("-inf"))
                a = F.softmax(sc, dim=-1)
                o = torch.matmul(a, v[:, hh])
                if hh == 1 or (not self.use_quantum and hh == 0):
                    attns.setdefault("classical", a)
            outs.append(o)
        out = torch.stack(outs, dim=1).transpose(1, 2).reshape(B, L, H * Dh)
        out = self.out_lin(out)
        return (out, attns) if return_attn else out


class TransformerBlock(nn.Module):
    def __init__(self, d_model, n_heads, ff_dim, use_quantum=False,
                 entangle="full", n_qubits=4, dropout=0.1):
        super().__init__()
        self.attn = MixedMultiHeadAttention(d_model, n_heads, use_quantum,
                                            entangle, n_qubits)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(nn.Linear(d_model, ff_dim), nn.GELU(),
                                nn.Linear(ff_dim, d_model))
        self.drop = nn.Dropout(dropout)

    def forward(self, x, key_mask=None, return_attn=False, debug=False):
        if return_attn:
            a_out, attns = self.attn(x, key_mask, return_attn=True, debug=debug)
        else:
            a_out, attns = self.attn(x, key_mask, debug=debug), None
        x = self.norm1(x + self.drop(a_out))
        x = self.norm2(x + self.drop(self.ff(x)))
        return (x, attns) if return_attn else x


class TextTransformer(nn.Module):
    def __init__(self, vocab_size, n_classes, d_model=64, n_heads=4, ff_dim=128,
                 max_len=40, use_quantum=True, entangle="full", n_qubits=4,
                 quantum_in_block=0, dropout=0.1):
        super().__init__()
        self.tok_emb = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.pos_emb = nn.Embedding(max_len, d_model)
        self.max_len = max_len
        self.blocks = nn.ModuleList([
            TransformerBlock(d_model, n_heads, ff_dim,
                             use_quantum=(use_quantum and b == quantum_in_block),
                             entangle=entangle, n_qubits=n_qubits, dropout=dropout)
            for b in range(2)])
        self.norm = nn.LayerNorm(d_model)
        self.head = nn.Linear(d_model, n_classes)

    def forward(self, input_ids, attn_mask, return_attn=False, debug=False):
        B, L = input_ids.shape
        L = min(L, self.max_len)
        input_ids = input_ids[:, :L]
        attn_mask = attn_mask[:, :L]
        pos = torch.arange(L, device=input_ids.device).unsqueeze(0).expand(B, L)
        x = self.tok_emb(input_ids) + self.pos_emb(pos)
        key_mask = attn_mask.unsqueeze(1)
        collected = {}
        for bi, blk in enumerate(self.blocks):
            if return_attn:
                x, attns = blk(x, key_mask, return_attn=True, debug=(debug and bi == 0))
                if attns:
                    collected[f"block{bi}"] = attns
            else:
                x = blk(x, key_mask, debug=(debug and bi == 0))
        x = self.norm(x)
        m = attn_mask.unsqueeze(-1).float()
        pooled = (x * m).sum(1) / m.sum(1).clamp(min=1.0)
        logits = self.head(pooled)
        return (logits, collected) if return_attn else logits


def attention_entropy(attn, key_mask=None, eps=1e-9):
    p = attn.clamp(min=eps)
    ent = -(p * p.log()).sum(-1)
    if key_mask is not None:
        valid = key_mask.squeeze(1).float()
        return ((ent * valid).sum() / valid.sum().clamp(min=1.0)).item()
    return ent.mean().item()


# =========================================================================== #
# Data utilities
# =========================================================================== #
def tokenize(s):
    return s.lower().split()


def build_vocab(examples, min_freq=2):
    from collections import Counter
    c = Counter()
    for e in examples:
        c.update(tokenize(e["text"]))
    v = {"<pad>": PAD, "<unk>": UNK}
    for w, f in c.most_common():
        if f >= min_freq:
            v[w] = len(v)
    return v


def encode(s, v, ml):
    return [v.get(t, UNK) for t in tokenize(s)][:ml]


def batchify(examples, v, ml, bs, shuffle, seed, device):
    idx = list(range(len(examples)))
    if shuffle:
        g = torch.Generator().manual_seed(seed)
        idx = torch.randperm(len(examples), generator=g).tolist()
    batches = []
    for i in range(0, len(examples), bs):
        chunk = [examples[j] for j in idx[i:i + bs]]
        seqs = [encode(e["text"], v, ml) for e in chunk]
        L = max(max((len(s) for s in seqs), default=1), 1)
        ids = torch.full((len(seqs), L), PAD, dtype=torch.long)
        m = torch.zeros((len(seqs), L), dtype=torch.long)
        for r, s in enumerate(seqs):
            if s:
                ids[r, :len(s)] = torch.tensor(s)
                m[r, :len(s)] = 1
        y = torch.tensor([e["label"] for e in chunk])
        batches.append((ids.to(device), m.to(device), y.to(device)))
    return batches


@torch.no_grad()
def accuracy(model, batches):
    model.eval()
    c = t = 0
    for ids, m, y in batches:
        c += (model(ids, m).argmax(-1) == y).sum().item()
        t += y.numel()
    return c / max(t, 1)


@torch.no_grad()
def mean_entropy(model, batches, max_batches=6):
    model.eval()
    q, cl = [], []
    for bi, (ids, m, y) in enumerate(batches):
        if bi >= max_batches:
            break
        _, attns = model(ids, m, return_attn=True)
        km = m[:, :ids.shape[1]].unsqueeze(1)
        # read entropy from whichever block holds the quantum head (any depth)
        qblk = next((d for d in attns.values() if "quantum" in d), {})
        if "quantum" in qblk:
            q.append(attention_entropy(qblk["quantum"], km))
        cblk = qblk if "classical" in qblk else \
               next((d for d in attns.values() if "classical" in d), {})
        if "classical" in cblk:
            cl.append(attention_entropy(cblk["classical"], km))
    return (sum(q) / len(q) if q else float("nan"),
            sum(cl) / len(cl) if cl else float("nan"))


# =========================================================================== #
# Train one (condition, seed) with val-based model selection
# =========================================================================== #
CONDITIONS = {
    "classical": dict(use_quantum=False, entangle="full"),
    "qnone":     dict(use_quantum=True,  entangle="none"),
    "qintra":    dict(use_quantum=True,  entangle="intra"),
    "qcross":    dict(use_quantum=True,  entangle="cross"),
    "qfull":     dict(use_quantum=True,  entangle="full"),
}


def run_one(cond, seed, data, vocab, n_classes, cfg):
    """cfg: dict with epochs, max_len, batch_size, d_model, n_heads, n_qubits,
    lr, qlr, device."""
    train_fit, val, test = data
    cc = CONDITIONS[cond]
    device = cfg["device"]
    torch.manual_seed(seed)
    model = TextTransformer(
        vocab_size=len(vocab), n_classes=n_classes,
        d_model=cfg["d_model"], n_heads=cfg["n_heads"], max_len=cfg["max_len"],
        use_quantum=cc["use_quantum"], entangle=cc["entangle"],
        n_qubits=cfg["n_qubits"],
        quantum_in_block=cfg.get("quantum_in_block", 0)).to(device)
    qp = [p for n, p in model.named_parameters() if "qweights" in n]
    cp = [p for n, p in model.named_parameters() if "qweights" not in n]
    groups = [{"params": cp, "lr": cfg["lr"]}]
    if qp:
        groups.append({"params": qp, "lr": cfg["qlr"]})
    opt = torch.optim.Adam(groups)
    val_b = batchify(val, vocab, cfg["max_len"], 128, False, 0, device)
    test_b = batchify(test, vocab, cfg["max_len"], 128, False, 0, device)
    best_val, test_at_best, best_ep = -1.0, 0.0, 0
    t0 = time.time()
    for ep in range(1, cfg["epochs"] + 1):
        model.train()
        for ids, m, y in batchify(train_fit, vocab, cfg["max_len"],
                                  cfg["batch_size"], True, 1000 * seed + ep, device):
            opt.zero_grad()
            F.cross_entropy(model(ids, m), y).backward()
            opt.step()
        va = accuracy(model, val_b)
        if va > best_val:
            best_val, test_at_best, best_ep = va, accuracy(model, test_b), ep
    h_q, h_c = mean_entropy(model, test_b)
    return dict(test_acc=test_at_best, val_acc=best_val, best_epoch=best_ep,
                H_quantum=h_q, H_classical=h_c,
                params=sum(p.numel() for p in model.parameters() if p.requires_grad),
                n_qubits=cfg["n_qubits"], n_heads=cfg["n_heads"],
                quantum_in_block=cfg.get("quantum_in_block", 0),
                seconds=round(time.time() - t0, 1))


def mean_std(xs):
    n = len(xs)
    mu = sum(xs) / n
    sd = (sum((x - mu) ** 2 for x in xs) / (n - 1)) ** 0.5 if n > 1 else 0.0
    return mu, sd


def permutation_test(a, b, max_exact=200000, n_random=100000, seed=0):
    a, b = list(a), list(b)
    na, nb = len(a), len(b)
    pooled = a + b
    obs = abs(sum(a) / na - sum(b) / nb)
    total = math.comb(na + nb, na)
    cnt = 0
    if total <= max_exact:
        for combo in itertools.combinations(range(na + nb), na):
            s = set(combo)
            ga = [pooled[i] for i in combo]
            gb = [pooled[i] for i in range(na + nb) if i not in s]
            if abs(sum(ga) / na - sum(gb) / nb) >= obs - 1e-12:
                cnt += 1
        return obs, cnt / total, f"exact ({total})"
    rng = torch.Generator().manual_seed(seed)
    for _ in range(n_random):
        perm = torch.randperm(na + nb, generator=rng).tolist()
        ga = [pooled[i] for i in perm[:na]]
        gb = [pooled[i] for i in perm[na:]]
        if abs(sum(ga) / na - sum(gb) / nb) >= obs - 1e-12:
            cnt += 1
    return obs, cnt / n_random, f"sampled ({n_random})"

# %% [markdown]
# ## 4 · Dataset config + load + fixed split

# %%
COARSE = ["ABBR","ENTY","DESC","HUM","LOC","NUM"]
C2I = {c:i for i,c in enumerate(COARSE)}
def load_dataset_examples():
    def rd(p):
        ex=[]
        for line in open(p,"rb"):
            line=line.replace(b"\xf0",b" ").strip().decode("latin-1")
            if not line: continue
            lab,_,t=line.partition(" "); c=lab.split(":")[0]
            if c in C2I and t: ex.append({"text":t,"label":C2I[c]})
        return ex
    return rd("trec/train.label"), rd("trec/test.label"), COARSE

# ---- experiment configuration ----
N_CLASSES   = 6
MAX_LEN     = 20
DEFAULT_N   = 2000      # train-fit size for experiments A, B, D
EPOCHS      = 20
VAL_SIZE    = 500
MIN_FREQ    = 2
SEEDS       = [0, 1, 2, 3, 4]       # set to [0,1,2] for a quick run
N_EFF       = [100, 250, 500, 1000, 2000]          # training sizes for the data-efficiency sweep

TRAIN_ALL, TEST_ALL, LABELS = load_dataset_examples()
assert len(LABELS) == N_CLASSES
print(f"{DATASET}: train={len(TRAIN_ALL)} test={len(TEST_ALL)} classes={N_CLASSES} {LABELS}")
from collections import Counter
print("label counts:", dict(Counter(e['label'] for e in TRAIN_ALL)))
_lens = sorted(len(tokenize(e['text'])) for e in TRAIN_ALL)
print(f"token length: median={_lens[len(_lens)//2]} p95={_lens[int(0.95*len(_lens))]} "
      f"max={_lens[-1]} | MAX_LEN={MAX_LEN}")
# Out:
# trec: train=5452 test=500 classes=6 ['ABBR', 'ENTY', 'DESC', 'HUM', 'LOC', 'NUM']
# label counts: {2: 1162, 1: 1250, 0: 86, 3: 1223, 5: 896, 4: 835}
# token length: median=10 p95=17 max=37 | MAX_LEN=20

# %% [markdown]
# ## 5 · Checkpointed experiment harness
# `run_experiment` saves to Drive after **every** (config, seed); re-running skips finished cells. Data/vocab are built per training size and cached.

# %%
def _load(path):
    return json.load(open(path)) if os.path.exists(path) else {}

def _save(path, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    tmp = path + ".tmp"
    json.dump(obj, open(tmp, "w"), indent=2)
    os.replace(tmp, path)            # avoids half-written checkpoints on interrupt

_data_cache = {}
def make_split(limit_train):
    g = torch.Generator().manual_seed(12345)
    tr = list(TRAIN_ALL)
    perm = torch.randperm(len(tr), generator=g).tolist()
    tr = [tr[i] for i in perm]
    if limit_train is not None:
        tr = tr[:limit_train + VAL_SIZE]
    val = tr[:VAL_SIZE]; train_fit = tr[VAL_SIZE:]
    vocab = build_vocab(train_fit, MIN_FREQ)
    return (train_fit, val, TEST_ALL), vocab, N_CLASSES

def get_data(limit_train):
    if limit_train not in _data_cache:
        _data_cache[limit_train] = make_split(limit_train)
    return _data_cache[limit_train]

BASE = dict(epochs=EPOCHS, max_len=MAX_LEN, batch_size=64, d_model=64,
            n_heads=4, n_qubits=4, lr=2e-3, qlr=1e-2, device=DEVICE)
def cfg(cond, key, **over):
    c = dict(BASE); c.update(over); c["cond"] = cond; c["key"] = key
    c.setdefault("limit_train", DEFAULT_N); return c

def run_experiment(exp_name, grid, seeds):
    path = os.path.join(RESULTS_DIR, exp_name + ".json")
    results = _load(path)
    t_start = time.time()
    for c in grid:
        key = c["key"]
        data, vocab, nc = get_data(c["limit_train"])
        results.setdefault(key, {})
        for s in seeds:
            if str(s) in results[key]:
                print(f"  skip {key} seed{s} (test={results[key][str(s)]['test_acc']:.4f})")
                continue
            print(f"  run  {key} seed{s} ...", flush=True)
            r = run_one(c["cond"], s, data, vocab, nc, c)
            results[key][str(s)] = r
            _save(path, results)
            print(f"       test={r['test_acc']:.4f} val={r['val_acc']:.4f} "
                  f"ep*={r['best_epoch']} H_q={r['H_quantum']:.3f} "
                  f"H_c={r['H_classical']:.3f} ({r['seconds']}s)", flush=True)
    print(f"[done] {exp_name}: {time.time()-t_start:.0f}s total -> {path}")
    return results

# %% [markdown]
# ## Experiment A — Architecture ablation (4 heads)
# The quantum head is **1 of 4** attention heads (the realistic setting). All five conditions share the same architecture; only the entangling-gate set changes.

# %%
gridA = [cfg(c, f"A_{c}") for c in
         ["classical","qnone","qintra","qcross","qfull"]]
run_experiment("expA_4head", gridA, SEEDS)
# Out:
#   run  A_classical seed0 ...
#        test=0.8100 val=0.7660 ep*=8 H_q=nan H_c=1.037 (16.5s)
#   run  A_classical seed1 ...
#        test=0.8320 val=0.7640 ep*=18 H_q=nan H_c=0.649 (15.6s)
#   run  A_classical seed2 ...
#        test=0.8300 val=0.7560 ep*=16 H_q=nan H_c=0.900 (15.8s)
#   run  A_classical seed3 ...
#        test=0.8320 val=0.7860 ep*=9 H_q=nan H_c=0.814 (16.5s)
#   run  A_classical seed4 ...
#        test=0.8140 val=0.7580 ep*=13 H_q=nan H_c=0.955 (15.9s)
#   run  A_qnone seed0 ...
#        test=0.8220 val=0.7660 ep*=16 H_q=1.669 H_c=0.824 (197.2s)
#   run  A_qnone seed1 ...
#        test=0.8240 val=0.7580 ep*=10 H_q=1.244 H_c=1.196 (218.2s)
#   run  A_qnone seed2 ...
#        test=0.8160 val=0.7600 ep*=19 H_q=1.132 H_c=0.870 (221.0s)
#   run  A_qnone seed3 ...
#        test=0.8200 val=0.7700 ep*=11 H_q=1.584 H_c=0.973 (206.9s)
#   run  A_qnone seed4 ...
#        test=0.8060 val=0.7420 ep*=9 H_q=1.523 H_c=1.007 (198.4s)
#   run  A_qintra seed0 ...
#        test=0.8380 val=0.7620 ep*=9 H_q=1.605 H_c=0.791 (214.6s)
#   run  A_qintra seed1 ...
#        test=0.8340 val=0.7580 ep*=15 H_q=1.103 H_c=1.059 (219.6s)
#   run  A_qintra seed2 ...
#        test=0.8240 val=0.7600 ep*=18 H_q=0.647 H_c=0.965 (209.5s)
#   run  A_qintra seed3 ...
#        test=0.8200 val=0.7900 ep*=19 H_q=1.706 H_c=0.862 (211.4s)
#   run  A_qintra seed4 ...
#        test=0.8080 val=0.7420 ep*=10 H_q=1.535 H_c=0.829 (196.1s)
#   run  A_qcross seed0 ...
#        test=0.8500 val=0.7780 ep*=20 H_q=0.948 H_c=0.747 (204.2s)
#   run  A_qcross seed1 ...
#        test=0.8200 val=0.7640 ep*=17 H_q=1.090 H_c=1.005 (206.2s)
#   run  A_qcross seed2 ...
#        test=0.8300 val=0.7460 ep*=18 H_q=0.622 H_c=0.900 (212.6s)
#   run  A_qcross seed3 ...
#        test=0.8360 val=0.7840 ep*=19 H_q=1.655 H_c=0.988 (207.8s)
#   run  A_qcross seed4 ...
#        test=0.8140 val=0.7560 ep*=9 H_q=1.409 H_c=0.916 (214.3s)
#   run  A_qfull seed0 ...
#        test=0.8340 val=0.7700 ep*=13 H_q=1.489 H_c=0.781 (228.8s)
#   run  A_qfull seed1 ...
#        test=0.8180 val=0.7580 ep*=14 H_q=1.074 H_c=1.051 (230.8s)
#   run  A_qfull seed2 ...
#        test=0.8100 val=0.7500 ep*=9 H_q=0.855 H_c=0.948 (213.6s)
#   run  A_qfull seed3 ...
#        test=0.8120 val=0.7720 ep*=11 H_q=1.723 H_c=1.008 (208.9s)
#   run  A_qfull seed4 ...
#        test=0.8040 val=0.7480 ep*=15 H_q=1.332 H_c=0.949 (210.3s)
# [done] expA_4head: 4317s total -> /content/drive/MyDrive/quantum_attention/trec/expA_4head.json
# {'A_classical': {'0': {'test_acc': 0.81,
#    'val_acc': 0.766,
#    'best_epoch': 8,
#    'H_quantum': nan,
#    'H_classical': 1.0365971624851227,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 16.5},
#   '1': {'test_acc': 0.832,
#    'val_acc': 0.764,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 0.6485866159200668,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 15.6},
#   '2': {'test_acc': 0.83,
#    'val_acc': 0.756,
#    'best_epoch': 16,
#    'H_quantum': nan,
#    'H_classical': 0.899865984916687,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 15.8},
#   '3': {'test_acc': 0.832,
#    'val_acc': 0.786,
#    'best_epoch': 9,
#    'H_quantum': nan,
#    'H_classical': 0.8139335215091705,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 16.5},
#   '4': {'test_acc': 0.814,
#    'val_acc': 0.758,
#    'best_epoch': 13,
#    'H_quantum': nan,
#    'H_classical': 0.9553664475679398,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 15.9}},
#  'A_qnone': {'0': {'test_acc': 0.822,
#    'val_acc': 0.766,
#    'best_epoch': 16,
#    'H_quantum': 1.669319599866867,
#    'H_classical': 0.8244677931070328,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 197.2},
#   '1': {'test_acc': 0.824,
#    'val_acc': 0.758,
#    'best_epoch': 10,
#    'H_quantum': 1.244344711303711,
#    'H_classical': 1.1960105001926422,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 218.2},
#   '2': {'test_acc': 0.816,
#    'val_acc': 0.76,
#    'best_epoch': 19,
#    'H_quantum': 1.131663292646408,
#    'H_classical': 0.8695641905069351,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 221.0},
#   '3': {'test_acc': 0.82,
#    'val_acc': 0.77,
#    'best_epoch': 11,
#    'H_quantum': 1.584077775478363,
#    'H_classical': 0.9725460261106491,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 206.9},
#   '4': {'test_acc': 0.806,
#    'val_acc': 0.742,
#    'best_epoch': 9,
#    'H_quantum': 1.5229251682758331,
#    'H_classical': 1.0069598257541656,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 198.4}},
#  'A_qintra': {'0': {'test_acc': 0.838,
#    'val_acc': 0.762,
#    'best_epoch': 9,
#    'H_quantum': 1.6051661670207977,
#    'H_classical': 0.7909208685159683,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 214.6},
#   '1': {'test_acc': 0.834,
#    'val_acc': 0.758,
#    'best_epoch': 15,
#    'H_quantum': 1.1034938097000122,
#    'H_classical': 1.0585638284683228,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 219.6},
#   '2': {'test_acc': 0.824,
#    'val_acc': 0.76,
#    'best_epoch': 18,
#    'H_quantum': 0.6470357030630112,
#    'H_classical': 0.9651685208082199,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 209.5},
#   '3': {'test_acc': 0.82,
#    'val_acc': 0.79,
#    'best_epoch': 19,
#    'H_quantum': 1.7063681185245514,
#    'H_classical': 0.8621241450309753,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 211.4},
#   '4': {'test_acc': 0.808,
#    'val_acc': 0.742,
#    'best_epoch': 10,
#    'H_quantum': 1.5351511538028717,
#    'H_classical': 0.8289942443370819,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 196.1}},
#  'A_qcross': {'0': {'test_acc': 0.85,
#    'val_acc': 0.778,
#    'best_epoch': 20,
#    'H_quantum': 0.9479328840970993,
#    'H_classical': 0.7471499592065811,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 204.2},
#   '1': {'test_acc': 0.82,
#    'val_acc': 0.764,
#    'best_epoch': 17,
#    'H_quantum': 1.0898671746253967,
#    'H_classical': 1.005077749490738,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 206.2},
#   '2': {'test_acc': 0.83,
#    'val_acc': 0.746,
#    'best_epoch': 18,
#    'H_quantum': 0.6224619597196579,
#    'H_classical': 0.9002053141593933,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 212.6},
#   '3': {'test_acc': 0.836,
#    'val_acc': 0.784,
#    'best_epoch': 19,
#    'H_quantum': 1.6548664271831512,
#    'H_classical': 0.9883086532354355,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 207.8},
#   '4': {'test_acc': 0.814,
#    'val_acc': 0.756,
#    'best_epoch': 9,
#    'H_quantum': 1.408781886100769,
#    'H_classical': 0.9159607887268066,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 214.3}},
#  'A_qfull': {'0': {'test_acc': 0.834,
#    'val_acc': 0.77,
#    'best_epoch': 13,
#    'H_quantum': 1.4893090724945068,
#    'H_classical': 0.7814028114080429,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 228.8},
#   '1': {'test_acc': 0.818,
#    'val_acc': 0.758,
#    'best_epoch': 14,
#    'H_quantum': 1.073854148387909,
#    'H_classical': 1.050966054201126,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 230.8},
#   '2': {'test_acc': 0.81,
#    'val_acc': 0.75,
#    'best_epoch': 9,
#    'H_quantum': 0.8550937920808792,
#    'H_classical': 0.94832544028759,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 213.6},
#   '3': {'test_acc': 0.812,
#    'val_acc': 0.772,
#    'best_epoch': 11,
#    'H_quantum': 1.7232805490493774,
#    'H_classical': 1.00816011428833,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 208.9},
#   '4': {'test_acc': 0.804,
#    'val_acc': 0.748,
#    'best_epoch': 15,
#    'H_quantum': 1.3319888710975647,
#    'H_classical': 0.9485975950956345,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 210.3}}}

# %% [markdown]
# ## Experiment B — Single-head ablation (dilution test)
# `n_heads=1`: the quantum circuit is the **only** attention mechanism. If entanglement matters at all, it should be most visible here, undiluted by parallel classical heads.

# %%
gridB = [cfg(c, f"B_{c}", n_heads=1) for c in
         ["classical","qnone","qintra","qcross","qfull"]]
run_experiment("expB_1head", gridB, SEEDS)
# Out:
#   run  B_classical seed0 ...
#        test=0.8400 val=0.7640 ep*=12 H_q=nan H_c=0.631 (11.8s)
#   run  B_classical seed1 ...
#        test=0.8360 val=0.7560 ep*=11 H_q=nan H_c=0.770 (11.9s)
#   run  B_classical seed2 ...
#        test=0.8180 val=0.7620 ep*=16 H_q=nan H_c=0.681 (11.8s)
#   run  B_classical seed3 ...
#        test=0.8080 val=0.7740 ep*=11 H_q=nan H_c=0.920 (11.9s)
#   run  B_classical seed4 ...
#        test=0.7920 val=0.7700 ep*=20 H_q=nan H_c=0.719 (12.0s)
#   run  B_qnone seed0 ...
#        test=0.8320 val=0.7940 ep*=20 H_q=1.538 H_c=nan (197.8s)
#   run  B_qnone seed1 ...
#        test=0.8100 val=0.7520 ep*=17 H_q=1.998 H_c=nan (184.0s)
#   run  B_qnone seed2 ...
#        test=0.8260 val=0.7820 ep*=16 H_q=1.369 H_c=nan (195.0s)
#   run  B_qnone seed3 ...
#        test=0.8240 val=0.7920 ep*=17 H_q=1.852 H_c=nan (184.6s)
#   run  B_qnone seed4 ...
#        test=0.8340 val=0.7720 ep*=15 H_q=1.748 H_c=nan (196.6s)
#   run  B_qintra seed0 ...
#        test=0.8180 val=0.7980 ep*=20 H_q=1.572 H_c=nan (199.7s)
#   run  B_qintra seed1 ...
#        test=0.8520 val=0.7720 ep*=16 H_q=1.866 H_c=nan (214.8s)
#   run  B_qintra seed2 ...
#        test=0.8220 val=0.7820 ep*=20 H_q=1.456 H_c=nan (194.4s)
#   run  B_qintra seed3 ...
#        test=0.8400 val=0.7840 ep*=14 H_q=1.949 H_c=nan (204.8s)
#   run  B_qintra seed4 ...
#        test=0.8260 val=0.7820 ep*=18 H_q=1.848 H_c=nan (199.8s)
#   run  B_qcross seed0 ...
#        test=0.8220 val=0.7900 ep*=14 H_q=1.408 H_c=nan (204.0s)
#   run  B_qcross seed1 ...
#        test=0.8220 val=0.7780 ep*=20 H_q=1.835 H_c=nan (222.6s)
#   run  B_qcross seed2 ...
#        test=0.8160 val=0.7680 ep*=15 H_q=1.420 H_c=nan (195.2s)
#   run  B_qcross seed3 ...
#        test=0.8140 val=0.7900 ep*=16 H_q=2.046 H_c=nan (197.5s)
#   run  B_qcross seed4 ...
#        test=0.8420 val=0.7840 ep*=18 H_q=1.864 H_c=nan (212.7s)
#   run  B_qfull seed0 ...
#        test=0.8440 val=0.8000 ep*=19 H_q=1.699 H_c=nan (202.8s)
#   run  B_qfull seed1 ...
#        test=0.8320 val=0.7700 ep*=14 H_q=1.909 H_c=nan (213.4s)
#   run  B_qfull seed2 ...
#        test=0.8240 val=0.7660 ep*=20 H_q=1.492 H_c=nan (219.5s)
#   run  B_qfull seed3 ...
#        test=0.8280 val=0.7760 ep*=9 H_q=1.950 H_c=nan (196.5s)
#   run  B_qfull seed4 ...
#        test=0.8100 val=0.7860 ep*=12 H_q=1.601 H_c=nan (213.7s)
# [done] expB_1head: 4110s total -> /content/drive/MyDrive/quantum_attention/trec/expB_1head.json
# {'B_classical': {'0': {'test_acc': 0.84,
#    'val_acc': 0.764,
#    'best_epoch': 12,
#    'H_quantum': nan,
#    'H_classical': 0.631220817565918,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 11.8},
#   '1': {'test_acc': 0.836,
#    'val_acc': 0.756,
#    'best_epoch': 11,
#    'H_quantum': nan,
#    'H_classical': 0.7704804390668869,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 11.9},
#   '2': {'test_acc': 0.818,
#    'val_acc': 0.762,
#    'best_epoch': 16,
#    'H_quantum': nan,
#    'H_classical': 0.6805109977722168,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 11.8},
#   '3': {'test_acc': 0.808,
#    'val_acc': 0.774,
#    'best_epoch': 11,
#    'H_quantum': nan,
#    'H_classical': 0.9201904684305191,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 11.9},
#   '4': {'test_acc': 0.792,
#    'val_acc': 0.77,
#    'best_epoch': 20,
#    'H_quantum': nan,
#    'H_classical': 0.7185104489326477,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 12.0}},
#  'B_qnone': {'0': {'test_acc': 0.832,
#    'val_acc': 0.794,
#    'best_epoch': 20,
#    'H_quantum': 1.5380986630916595,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 197.8},
#   '1': {'test_acc': 0.81,
#    'val_acc': 0.752,
#    'best_epoch': 17,
#    'H_quantum': 1.9982735216617584,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 184.0},
#   '2': {'test_acc': 0.826,
#    'val_acc': 0.782,
#    'best_epoch': 16,
#    'H_quantum': 1.368741363286972,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 195.0},
#   '3': {'test_acc': 0.824,
#    'val_acc': 0.792,
#    'best_epoch': 17,
#    'H_quantum': 1.8524765968322754,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 184.6},
#   '4': {'test_acc': 0.834,
#    'val_acc': 0.772,
#    'best_epoch': 15,
#    'H_quantum': 1.7476724982261658,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 196.6}},
#  'B_qintra': {'0': {'test_acc': 0.818,
#    'val_acc': 0.798,
#    'best_epoch': 20,
#    'H_quantum': 1.5721888840198517,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 199.7},
#   '1': {'test_acc': 0.852,
#    'val_acc': 0.772,
#    'best_epoch': 16,
#    'H_quantum': 1.8658412098884583,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 214.8},
#   '2': {'test_acc': 0.822,
#    'val_acc': 0.782,
#    'best_epoch': 20,
#    'H_quantum': 1.4564965069293976,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 194.4},
#   '3': {'test_acc': 0.84,
#    'val_acc': 0.784,
#    'best_epoch': 14,
#    'H_quantum': 1.9493817389011383,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 204.8},
#   '4': {'test_acc': 0.826,
#    'val_acc': 0.782,
#    'best_epoch': 18,
#    'H_quantum': 1.84842911362648,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 199.8}},
#  'B_qcross': {'0': {'test_acc': 0.822,
#    'val_acc': 0.79,
#    'best_epoch': 14,
#    'H_quantum': 1.4075585007667542,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 204.0},
#   '1': {'test_acc': 0.822,
#    'val_acc': 0.778,
#    'best_epoch': 20,
#    'H_quantum': 1.8350474536418915,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 222.6},
#   '2': {'test_acc': 0.816,
#    'val_acc': 0.768,
#    'best_epoch': 15,
#    'H_quantum': 1.419585108757019,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 195.2},
#   '3': {'test_acc': 0.814,
#    'val_acc': 0.79,
#    'best_epoch': 16,
#    'H_quantum': 2.046177566051483,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 197.5},
#   '4': {'test_acc': 0.842,
#    'val_acc': 0.784,
#    'best_epoch': 18,
#    'H_quantum': 1.8644674718379974,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 212.7}},
#  'B_qfull': {'0': {'test_acc': 0.844,
#    'val_acc': 0.8,
#    'best_epoch': 19,
#    'H_quantum': 1.6987845301628113,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 202.8},
#   '1': {'test_acc': 0.832,
#    'val_acc': 0.77,
#    'best_epoch': 14,
#    'H_quantum': 1.909472018480301,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 213.4},
#   '2': {'test_acc': 0.824,
#    'val_acc': 0.766,
#    'best_epoch': 20,
#    'H_quantum': 1.4915624260902405,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 219.5},
#   '3': {'test_acc': 0.828,
#    'val_acc': 0.776,
#    'best_epoch': 9,
#    'H_quantum': 1.9497343003749847,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 196.5},
#   '4': {'test_acc': 0.81,
#    'val_acc': 0.786,
#    'best_epoch': 12,
#    'H_quantum': 1.6010159254074097,
#    'H_classical': nan,
#    'params': 168995,
#    'n_qubits': 4,
#    'n_heads': 1,
#    'seconds': 213.7}}}

# %% [markdown]
# ## Experiment C — Data-efficiency
# Accuracy vs training size. Quantum methods are most defensible in the low-data regime, so this curve is where a positive effect is most likely to appear.

# %%
gridC = [cfg(c, f"C_{c}_N{N}", limit_train=N)
         for N in N_EFF
         for c in ["classical","qnone","qcross","qfull"]]
run_experiment("expC_dataeff", gridC, SEEDS)
# Out:
#   run  C_classical_N100 seed0 ...
#        test=0.5840 val=0.5580 ep*=18 H_q=nan H_c=1.050 (1.7s)
#   run  C_classical_N100 seed1 ...
#        test=0.6220 val=0.5540 ep*=18 H_q=nan H_c=1.099 (1.7s)
#   run  C_classical_N100 seed2 ...
#        test=0.5560 val=0.4920 ep*=18 H_q=nan H_c=1.099 (1.8s)
#   run  C_classical_N100 seed3 ...
#        test=0.5660 val=0.5540 ep*=14 H_q=nan H_c=1.244 (1.6s)
#   run  C_classical_N100 seed4 ...
#        test=0.6120 val=0.5160 ep*=18 H_q=nan H_c=1.197 (1.9s)
#   run  C_qnone_N100 seed0 ...
#        test=0.5100 val=0.5380 ep*=16 H_q=0.945 H_c=1.170 (29.6s)
#   run  C_qnone_N100 seed1 ...
#        test=0.5500 val=0.5240 ep*=17 H_q=1.027 H_c=0.864 (26.5s)
#   run  C_qnone_N100 seed2 ...
#        test=0.5300 val=0.4980 ep*=13 H_q=1.104 H_c=0.996 (25.0s)
#   run  C_qnone_N100 seed3 ...
#        test=0.5900 val=0.5440 ep*=20 H_q=1.371 H_c=1.179 (25.3s)
#   run  C_qnone_N100 seed4 ...
#        test=0.5860 val=0.5320 ep*=11 H_q=1.028 H_c=1.054 (25.7s)
#   run  C_qcross_N100 seed0 ...
#        test=0.5120 val=0.5400 ep*=16 H_q=0.922 H_c=1.170 (31.8s)
#   run  C_qcross_N100 seed1 ...
#        test=0.5260 val=0.5340 ep*=15 H_q=0.863 H_c=0.865 (29.8s)
#   run  C_qcross_N100 seed2 ...
#        test=0.4300 val=0.4920 ep*=13 H_q=1.084 H_c=0.986 (28.5s)
#   run  C_qcross_N100 seed3 ...
#        test=0.5680 val=0.5580 ep*=20 H_q=1.247 H_c=1.168 (30.1s)
#   run  C_qcross_N100 seed4 ...
#        test=0.5500 val=0.5340 ep*=13 H_q=0.974 H_c=1.054 (28.5s)
#   run  C_qfull_N100 seed0 ...
#        test=0.5220 val=0.5340 ep*=15 H_q=0.929 H_c=1.169 (31.5s)
#   run  C_qfull_N100 seed1 ...
#        test=0.5320 val=0.5360 ep*=12 H_q=0.946 H_c=0.871 (28.4s)
#   run  C_qfull_N100 seed2 ...
#        test=0.4160 val=0.4920 ep*=15 H_q=1.015 H_c=0.993 (29.8s)
#   run  C_qfull_N100 seed3 ...
#        test=0.5240 val=0.5640 ep*=15 H_q=1.347 H_c=1.173 (28.4s)
#   run  C_qfull_N100 seed4 ...
#        test=0.5520 val=0.5400 ep*=14 H_q=1.014 H_c=1.066 (31.3s)
#   run  C_classical_N250 seed0 ...
#        test=0.6820 val=0.6200 ep*=15 H_q=nan H_c=0.995 (2.6s)
#   run  C_classical_N250 seed1 ...
#        test=0.6620 val=0.6220 ep*=10 H_q=nan H_c=1.070 (2.6s)
#   run  C_classical_N250 seed2 ...
#        test=0.6780 val=0.6100 ep*=13 H_q=nan H_c=1.085 (2.8s)
#   run  C_classical_N250 seed3 ...
#        test=0.6380 val=0.6240 ep*=17 H_q=nan H_c=1.135 (2.6s)
#   run  C_classical_N250 seed4 ...
#        test=0.6480 val=0.5940 ep*=12 H_q=nan H_c=1.066 (2.5s)
#   run  C_qnone_N250 seed0 ...
#        test=0.6700 val=0.6140 ep*=18 H_q=0.885 H_c=1.342 (40.5s)
#   run  C_qnone_N250 seed1 ...
#        test=0.6360 val=0.6160 ep*=17 H_q=1.146 H_c=1.093 (41.8s)
#   run  C_qnone_N250 seed2 ...
#        test=0.6900 val=0.5800 ep*=12 H_q=0.757 H_c=1.185 (39.5s)
#   run  C_qnone_N250 seed3 ...
#        test=0.6580 val=0.6220 ep*=11 H_q=1.280 H_c=1.165 (38.0s)
#   run  C_qnone_N250 seed4 ...
#        test=0.6120 val=0.5920 ep*=15 H_q=1.120 H_c=1.005 (37.5s)
#   run  C_qcross_N250 seed0 ...
#        test=0.6680 val=0.6140 ep*=17 H_q=0.821 H_c=1.389 (41.7s)
#   run  C_qcross_N250 seed1 ...
#        test=0.6360 val=0.6140 ep*=10 H_q=1.243 H_c=1.124 (41.4s)
#   run  C_qcross_N250 seed2 ...
#        test=0.6940 val=0.5880 ep*=14 H_q=0.989 H_c=1.148 (43.5s)
#   run  C_qcross_N250 seed3 ...
#        test=0.6200 val=0.6280 ep*=11 H_q=1.182 H_c=1.136 (39.6s)
#   run  C_qcross_N250 seed4 ...
#        test=0.6480 val=0.5980 ep*=20 H_q=1.195 H_c=0.972 (42.1s)
#   run  C_qfull_N250 seed0 ...
#        test=0.6580 val=0.6220 ep*=18 H_q=0.810 H_c=1.356 (44.0s)
#   run  C_qfull_N250 seed1 ...
#        test=0.6280 val=0.6140 ep*=10 H_q=1.186 H_c=1.183 (44.4s)
#   run  C_qfull_N250 seed2 ...
#        test=0.6900 val=0.5740 ep*=14 H_q=0.849 H_c=1.149 (44.9s)
#   run  C_qfull_N250 seed3 ...
#        test=0.6600 val=0.6280 ep*=10 H_q=1.275 H_c=1.160 (43.6s)
#   run  C_qfull_N250 seed4 ...
#        test=0.6580 val=0.6040 ep*=18 H_q=1.082 H_c=0.960 (44.7s)
#   run  C_classical_N500 seed0 ...
#        test=0.7420 val=0.7040 ep*=16 H_q=nan H_c=1.086 (4.5s)
#   run  C_classical_N500 seed1 ...
#        test=0.7400 val=0.6700 ep*=19 H_q=nan H_c=0.732 (4.7s)
#   run  C_classical_N500 seed2 ...
#        test=0.7300 val=0.6760 ep*=18 H_q=nan H_c=1.094 (4.5s)
#   run  C_classical_N500 seed3 ...
#        test=0.7200 val=0.6780 ep*=10 H_q=nan H_c=1.227 (4.7s)
#   run  C_classical_N500 seed4 ...
#        test=0.7680 val=0.7120 ep*=18 H_q=nan H_c=0.962 (4.6s)
#   run  C_qnone_N500 seed0 ...
#        test=0.7080 val=0.6680 ep*=10 H_q=1.256 H_c=1.191 (62.7s)
#   run  C_qnone_N500 seed1 ...
#        test=0.7100 val=0.6580 ep*=15 H_q=1.302 H_c=1.112 (61.1s)
#   run  C_qnone_N500 seed2 ...
#        test=0.7000 val=0.6780 ep*=11 H_q=0.963 H_c=1.100 (67.4s)
#   run  C_qnone_N500 seed3 ...
#        test=0.7080 val=0.6720 ep*=7 H_q=1.227 H_c=0.837 (64.5s)
#   run  C_qnone_N500 seed4 ...
#        test=0.7300 val=0.6940 ep*=8 H_q=1.519 H_c=0.667 (59.8s)
#   run  C_qcross_N500 seed0 ...
#        test=0.7040 val=0.6780 ep*=16 H_q=1.182 H_c=1.196 (65.8s)
#   run  C_qcross_N500 seed1 ...
#        test=0.7140 val=0.6940 ep*=19 H_q=1.219 H_c=1.094 (68.8s)
#   run  C_qcross_N500 seed2 ...
#        test=0.6920 val=0.6680 ep*=11 H_q=1.109 H_c=1.086 (67.9s)
#   run  C_qcross_N500 seed3 ...
#        test=0.7400 val=0.6680 ep*=16 H_q=1.436 H_c=0.803 (67.5s)
#   run  C_qcross_N500 seed4 ...
#        test=0.7920 val=0.7000 ep*=17 H_q=1.404 H_c=0.649 (67.0s)
#   run  C_qfull_N500 seed0 ...
#        test=0.6960 val=0.6780 ep*=14 H_q=1.170 H_c=1.029 (62.5s)
#   run  C_qfull_N500 seed1 ...
#        test=0.7100 val=0.6860 ep*=15 H_q=1.129 H_c=1.040 (67.0s)
#   run  C_qfull_N500 seed2 ...
#        test=0.7320 val=0.6720 ep*=18 H_q=1.132 H_c=1.042 (65.6s)
#   run  C_qfull_N500 seed3 ...
#        test=0.7580 val=0.6600 ep*=14 H_q=1.381 H_c=0.839 (66.8s)
#   run  C_qfull_N500 seed4 ...
#        test=0.7580 val=0.6920 ep*=17 H_q=1.369 H_c=0.614 (67.8s)
#   run  C_classical_N1000 seed0 ...
#        test=0.8160 val=0.7300 ep*=7 H_q=nan H_c=0.873 (7.8s)
#   run  C_classical_N1000 seed1 ...
#        test=0.7900 val=0.7100 ep*=12 H_q=nan H_c=1.076 (7.7s)
#   run  C_classical_N1000 seed2 ...
#        test=0.7480 val=0.7520 ep*=13 H_q=nan H_c=0.589 (7.7s)
#   run  C_classical_N1000 seed3 ...
#        test=0.7820 val=0.7280 ep*=10 H_q=nan H_c=0.819 (7.7s)
#   run  C_classical_N1000 seed4 ...
#        test=0.7840 val=0.7380 ep*=14 H_q=nan H_c=1.080 (7.7s)
#   run  C_qnone_N1000 seed0 ...
#        test=0.7640 val=0.7200 ep*=15 H_q=1.280 H_c=1.121 (98.3s)
#   run  C_qnone_N1000 seed1 ...
#        test=0.7820 val=0.7320 ep*=18 H_q=1.532 H_c=0.661 (100.8s)
#   run  C_qnone_N1000 seed2 ...
#        test=0.8020 val=0.7520 ep*=15 H_q=1.405 H_c=1.068 (104.7s)
#   run  C_qnone_N1000 seed3 ...
#        test=0.7540 val=0.7340 ep*=9 H_q=1.201 H_c=1.213 (102.8s)
#   run  C_qnone_N1000 seed4 ...
#        test=0.7780 val=0.7360 ep*=12 H_q=0.848 H_c=0.943 (105.9s)
#   run  C_qcross_N1000 seed0 ...
#        test=0.8080 val=0.7220 ep*=18 H_q=1.279 H_c=1.148 (111.9s)
#   run  C_qcross_N1000 seed1 ...
#        test=0.7880 val=0.7280 ep*=15 H_q=1.415 H_c=0.674 (112.2s)
#   run  C_qcross_N1000 seed2 ...
#        test=0.7980 val=0.7680 ep*=14 H_q=1.403 H_c=1.017 (107.9s)
#   run  C_qcross_N1000 seed3 ...
#        test=0.7460 val=0.7440 ep*=13 H_q=1.210 H_c=1.242 (100.5s)
#   run  C_qcross_N1000 seed4 ...
#        test=0.8160 val=0.7460 ep*=15 H_q=1.250 H_c=1.040 (106.5s)
#   run  C_qfull_N1000 seed0 ...
#        test=0.8040 val=0.7280 ep*=15 H_q=1.191 H_c=1.154 (109.3s)
#   run  C_qfull_N1000 seed1 ...
#        test=0.7740 val=0.7200 ep*=18 H_q=1.594 H_c=0.712 (105.6s)
#   run  C_qfull_N1000 seed2 ...
#        test=0.7900 val=0.7420 ep*=17 H_q=1.426 H_c=1.046 (113.0s)
#   run  C_qfull_N1000 seed3 ...
#        test=0.7540 val=0.7240 ep*=12 H_q=1.411 H_c=1.229 (113.3s)
#   run  C_qfull_N1000 seed4 ...
#        test=0.7780 val=0.7280 ep*=19 H_q=1.243 H_c=1.058 (112.9s)
#   run  C_classical_N2000 seed0 ...
#        test=0.8100 val=0.7660 ep*=8 H_q=nan H_c=1.037 (14.2s)
#   run  C_classical_N2000 seed1 ...
#        test=0.8320 val=0.7640 ep*=18 H_q=nan H_c=0.649 (14.6s)
#   run  C_classical_N2000 seed2 ...
#        test=0.8300 val=0.7560 ep*=16 H_q=nan H_c=0.900 (14.6s)
#   run  C_classical_N2000 seed3 ...
#        test=0.8320 val=0.7860 ep*=9 H_q=nan H_c=0.814 (14.6s)
#   run  C_classical_N2000 seed4 ...
#        test=0.8140 val=0.7580 ep*=13 H_q=nan H_c=0.955 (14.1s)
#   run  C_qnone_N2000 seed0 ...
#        test=0.8220 val=0.7660 ep*=16 H_q=1.669 H_c=0.824 (177.7s)
#   run  C_qnone_N2000 seed1 ...
#        test=0.8240 val=0.7580 ep*=10 H_q=1.244 H_c=1.196 (168.3s)
#   run  C_qnone_N2000 seed2 ...
#        test=0.8160 val=0.7600 ep*=19 H_q=1.132 H_c=0.870 (173.0s)
#   run  C_qnone_N2000 seed3 ...
#        test=0.8200 val=0.7700 ep*=11 H_q=1.584 H_c=0.973 (163.9s)
#   run  C_qnone_N2000 seed4 ...
#        test=0.8060 val=0.7420 ep*=9 H_q=1.523 H_c=1.007 (178.4s)
#   run  C_qcross_N2000 seed0 ...
#        test=0.8500 val=0.7780 ep*=20 H_q=0.948 H_c=0.747 (188.7s)
#   run  C_qcross_N2000 seed1 ...
#        test=0.8200 val=0.7640 ep*=17 H_q=1.090 H_c=1.005 (182.3s)
#   run  C_qcross_N2000 seed2 ...
#        test=0.8300 val=0.7460 ep*=18 H_q=0.622 H_c=0.900 (193.2s)
#   run  C_qcross_N2000 seed3 ...
#        test=0.8360 val=0.7840 ep*=19 H_q=1.655 H_c=0.988 (190.8s)
#   run  C_qcross_N2000 seed4 ...
#        test=0.8140 val=0.7560 ep*=9 H_q=1.409 H_c=0.916 (182.7s)
#   run  C_qfull_N2000 seed0 ...
#        test=0.8340 val=0.7700 ep*=13 H_q=1.489 H_c=0.781 (186.2s)
#   run  C_qfull_N2000 seed1 ...
#        test=0.8180 val=0.7580 ep*=14 H_q=1.074 H_c=1.051 (194.9s)
#   run  C_qfull_N2000 seed2 ...
#        test=0.8100 val=0.7500 ep*=9 H_q=0.855 H_c=0.948 (190.2s)
#   run  C_qfull_N2000 seed3 ...
#        test=0.8120 val=0.7720 ep*=11 H_q=1.723 H_c=1.008 (191.9s)
#   run  C_qfull_N2000 seed4 ...
#        test=0.8040 val=0.7480 ep*=15 H_q=1.332 H_c=0.949 (188.4s)
# [done] expC_dataeff: 6556s total -> /content/drive/MyDrive/quantum_attention/trec/expC_dataeff.json
# {'C_classical_N100': {'0': {'test_acc': 0.584,
#    'val_acc': 0.558,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 1.050052285194397,
#    'params': 74182,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 1.7},
#   '1': {'test_acc': 0.622,
#    'val_acc': 0.554,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 1.0985716879367828,
#    'params': 74182,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 1.7},
#   '2': {'test_acc': 0.556,
#    'val_acc': 0.492,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 1.0993590950965881,
#    'params': 74182,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 1.8},
#   '3': {'test_acc': 0.566,
#    'val_acc': 0.554,
#    'best_epoch': 14,
#    'H_quantum': nan,
#    'H_classical': 1.244373857975006,
#    'params': 74182,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 1.6},
#   '4': {'test_acc': 0.612,
#    'val_acc': 0.516,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 1.1966696381568909,
#    'params': 74182,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 1.9}},
#  'C_qnone_N100': {'0': {'test_acc': 0.51,
#    'val_acc': 0.538,
#    'best_epoch': 16,
#    'H_quantum': 0.9448737800121307,
#    'H_classical': 1.1701592206954956,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 29.6},
#   '1': {'test_acc': 0.55,
#    'val_acc': 0.524,
#    'best_epoch': 17,
#    'H_quantum': 1.0271384716033936,
#    'H_classical': 0.8641343116760254,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 26.5},
#   '2': {'test_acc': 0.53,
#    'val_acc': 0.498,
#    'best_epoch': 13,
#    'H_quantum': 1.1037585735321045,
#    'H_classical': 0.9958353191614151,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 25.0},
#   '3': {'test_acc': 0.59,
#    'val_acc': 0.544,
#    'best_epoch': 20,
#    'H_quantum': 1.3713369071483612,
#    'H_classical': 1.1785072982311249,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 25.3},
#   '4': {'test_acc': 0.586,
#    'val_acc': 0.532,
#    'best_epoch': 11,
#    'H_quantum': 1.027851402759552,
#    'H_classical': 1.0536108314990997,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 25.7}},
#  'C_qcross_N100': {'0': {'test_acc': 0.512,
#    'val_acc': 0.54,
#    'best_epoch': 16,
#    'H_quantum': 0.9219442307949066,
#    'H_classical': 1.1704144179821014,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 31.8},
#   '1': {'test_acc': 0.526,
#    'val_acc': 0.534,
#    'best_epoch': 15,
#    'H_quantum': 0.8628237843513489,
#    'H_classical': 0.8650851100683212,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 29.8},
#   '2': {'test_acc': 0.43,
#    'val_acc': 0.492,
#    'best_epoch': 13,
#    'H_quantum': 1.084149956703186,
#    'H_classical': 0.9862565249204636,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 28.5},
#   '3': {'test_acc': 0.568,
#    'val_acc': 0.558,
#    'best_epoch': 20,
#    'H_quantum': 1.246881753206253,
#    'H_classical': 1.168402910232544,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 30.1},
#   '4': {'test_acc': 0.55,
#    'val_acc': 0.534,
#    'best_epoch': 13,
#    'H_quantum': 0.9736616462469101,
#    'H_classical': 1.0544385612010956,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 28.5}},
#  'C_qfull_N100': {'0': {'test_acc': 0.522,
#    'val_acc': 0.534,
#    'best_epoch': 15,
#    'H_quantum': 0.9286482632160187,
#    'H_classical': 1.1691692173480988,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 31.5},
#   '1': {'test_acc': 0.532,
#    'val_acc': 0.536,
#    'best_epoch': 12,
#    'H_quantum': 0.9464273303747177,
#    'H_classical': 0.8709511756896973,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 28.4},
#   '2': {'test_acc': 0.416,
#    'val_acc': 0.492,
#    'best_epoch': 15,
#    'H_quantum': 1.0154686868190765,
#    'H_classical': 0.9930930137634277,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 29.8},
#   '3': {'test_acc': 0.524,
#    'val_acc': 0.564,
#    'best_epoch': 15,
#    'H_quantum': 1.3466964960098267,
#    'H_classical': 1.1729646623134613,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 28.4},
#   '4': {'test_acc': 0.552,
#    'val_acc': 0.54,
#    'best_epoch': 14,
#    'H_quantum': 1.0136227309703827,
#    'H_classical': 1.0663582384586334,
#    'params': 74275,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 31.3}},
#  'C_classical_N250': {'0': {'test_acc': 0.682,
#    'val_acc': 0.62,
#    'best_epoch': 15,
#    'H_quantum': nan,
#    'H_classical': 0.9952921718358994,
#    'params': 82310,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 2.6},
#   '1': {'test_acc': 0.662,
#    'val_acc': 0.622,
#    'best_epoch': 10,
#    'H_quantum': nan,
#    'H_classical': 1.070450246334076,
#    'params': 82310,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 2.6},
#   '2': {'test_acc': 0.678,
#    'val_acc': 0.61,
#    'best_epoch': 13,
#    'H_quantum': nan,
#    'H_classical': 1.0853387415409088,
#    'params': 82310,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 2.8},
#   '3': {'test_acc': 0.638,
#    'val_acc': 0.624,
#    'best_epoch': 17,
#    'H_quantum': nan,
#    'H_classical': 1.1350797712802887,
#    'params': 82310,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 2.6},
#   '4': {'test_acc': 0.648,
#    'val_acc': 0.594,
#    'best_epoch': 12,
#    'H_quantum': nan,
#    'H_classical': 1.0661218464374542,
#    'params': 82310,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 2.5}},
#  'C_qnone_N250': {'0': {'test_acc': 0.67,
#    'val_acc': 0.614,
#    'best_epoch': 18,
#    'H_quantum': 0.8845354467630386,
#    'H_classical': 1.3422935605049133,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 40.5},
#   '1': {'test_acc': 0.636,
#    'val_acc': 0.616,
#    'best_epoch': 17,
#    'H_quantum': 1.1455819308757782,
#    'H_classical': 1.0930556952953339,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 41.8},
#   '2': {'test_acc': 0.69,
#    'val_acc': 0.58,
#    'best_epoch': 12,
#    'H_quantum': 0.7573407590389252,
#    'H_classical': 1.1852404475212097,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 39.5},
#   '3': {'test_acc': 0.658,
#    'val_acc': 0.622,
#    'best_epoch': 11,
#    'H_quantum': 1.279762864112854,
#    'H_classical': 1.1654973924160004,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 38.0},
#   '4': {'test_acc': 0.612,
#    'val_acc': 0.592,
#    'best_epoch': 15,
#    'H_quantum': 1.1198716163635254,
#    'H_classical': 1.0046304017305374,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 37.5}},
#  'C_qcross_N250': {'0': {'test_acc': 0.668,
#    'val_acc': 0.614,
#    'best_epoch': 17,
#    'H_quantum': 0.8214221596717834,
#    'H_classical': 1.388551414012909,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 41.7},
#   '1': {'test_acc': 0.636,
#    'val_acc': 0.614,
#    'best_epoch': 10,
#    'H_quantum': 1.2434623539447784,
#    'H_classical': 1.1239047944545746,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 41.4},
#   '2': {'test_acc': 0.694,
#    'val_acc': 0.588,
#    'best_epoch': 14,
#    'H_quantum': 0.9893633276224136,
#    'H_classical': 1.1484078764915466,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 43.5},
#   '3': {'test_acc': 0.62,
#    'val_acc': 0.628,
#    'best_epoch': 11,
#    'H_quantum': 1.1823106110095978,
#    'H_classical': 1.136136770248413,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 39.6},
#   '4': {'test_acc': 0.648,
#    'val_acc': 0.598,
#    'best_epoch': 20,
#    'H_quantum': 1.1950587332248688,
#    'H_classical': 0.971821516752243,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 42.1}},
#  'C_qfull_N250': {'0': {'test_acc': 0.658,
#    'val_acc': 0.622,
#    'best_epoch': 18,
#    'H_quantum': 0.809911385178566,
#    'H_classical': 1.3555221557617188,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 44.0},
#   '1': {'test_acc': 0.628,
#    'val_acc': 0.614,
#    'best_epoch': 10,
#    'H_quantum': 1.1859888434410095,
#    'H_classical': 1.183147370815277,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 44.4},
#   '2': {'test_acc': 0.69,
#    'val_acc': 0.574,
#    'best_epoch': 14,
#    'H_quantum': 0.8493792563676834,
#    'H_classical': 1.1488538682460785,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 44.9},
#   '3': {'test_acc': 0.66,
#    'val_acc': 0.628,
#    'best_epoch': 10,
#    'H_quantum': 1.2752845883369446,
#    'H_classical': 1.160286396741867,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 43.6},
#   '4': {'test_acc': 0.658,
#    'val_acc': 0.604,
#    'best_epoch': 18,
#    'H_quantum': 1.0821536183357239,
#    'H_classical': 0.9603441208600998,
#    'params': 82403,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 44.7}},
#  'C_classical_N500': {'0': {'test_acc': 0.742,
#    'val_acc': 0.704,
#    'best_epoch': 16,
#    'H_quantum': nan,
#    'H_classical': 1.085670292377472,
#    'params': 95174,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 4.5},
#   '1': {'test_acc': 0.74,
#    'val_acc': 0.67,
#    'best_epoch': 19,
#    'H_quantum': nan,
#    'H_classical': 0.7324769496917725,
#    'params': 95174,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 4.7},
#   '2': {'test_acc': 0.73,
#    'val_acc': 0.676,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 1.0944273471832275,
#    'params': 95174,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 4.5},
#   '3': {'test_acc': 0.72,
#    'val_acc': 0.678,
#    'best_epoch': 10,
#    'H_quantum': nan,
#    'H_classical': 1.2274531126022339,
#    'params': 95174,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 4.7},
#   '4': {'test_acc': 0.768,
#    'val_acc': 0.712,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 0.9619422107934952,
#    'params': 95174,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 4.6}},
#  'C_qnone_N500': {'0': {'test_acc': 0.708,
#    'val_acc': 0.668,
#    'best_epoch': 10,
#    'H_quantum': 1.2555512487888336,
#    'H_classical': 1.1911338865756989,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 62.7},
#   '1': {'test_acc': 0.71,
#    'val_acc': 0.658,
#    'best_epoch': 15,
#    'H_quantum': 1.3015265762805939,
#    'H_classical': 1.1118895411491394,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 61.1},
#   '2': {'test_acc': 0.7,
#    'val_acc': 0.678,
#    'best_epoch': 11,
#    'H_quantum': 0.9634749740362167,
#    'H_classical': 1.0997875332832336,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.4},
#   '3': {'test_acc': 0.708,
#    'val_acc': 0.672,
#    'best_epoch': 7,
#    'H_quantum': 1.2267846167087555,
#    'H_classical': 0.8374963849782944,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 64.5},
#   '4': {'test_acc': 0.73,
#    'val_acc': 0.694,
#    'best_epoch': 8,
#    'H_quantum': 1.5187664926052094,
#    'H_classical': 0.6672715395689011,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 59.8}},
#  'C_qcross_N500': {'0': {'test_acc': 0.704,
#    'val_acc': 0.678,
#    'best_epoch': 16,
#    'H_quantum': 1.1824834048748016,
#    'H_classical': 1.1957023441791534,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 65.8},
#   '1': {'test_acc': 0.714,
#    'val_acc': 0.694,
#    'best_epoch': 19,
#    'H_quantum': 1.2189083397388458,
#    'H_classical': 1.0938596427440643,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 68.8},
#   '2': {'test_acc': 0.692,
#    'val_acc': 0.668,
#    'best_epoch': 11,
#    'H_quantum': 1.1088466048240662,
#    'H_classical': 1.0859353244304657,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.9},
#   '3': {'test_acc': 0.74,
#    'val_acc': 0.668,
#    'best_epoch': 16,
#    'H_quantum': 1.4361199736595154,
#    'H_classical': 0.8029392063617706,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.5},
#   '4': {'test_acc': 0.792,
#    'val_acc': 0.7,
#    'best_epoch': 17,
#    'H_quantum': 1.4035476744174957,
#    'H_classical': 0.6493892967700958,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.0}},
#  'C_qfull_N500': {'0': {'test_acc': 0.696,
#    'val_acc': 0.678,
#    'best_epoch': 14,
#    'H_quantum': 1.1699434220790863,
#    'H_classical': 1.0290605425834656,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 62.5},
#   '1': {'test_acc': 0.71,
#    'val_acc': 0.686,
#    'best_epoch': 15,
#    'H_quantum': 1.1288098990917206,
#    'H_classical': 1.0399999618530273,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.0},
#   '2': {'test_acc': 0.732,
#    'val_acc': 0.672,
#    'best_epoch': 18,
#    'H_quantum': 1.1321824789047241,
#    'H_classical': 1.042229413986206,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 65.6},
#   '3': {'test_acc': 0.758,
#    'val_acc': 0.66,
#    'best_epoch': 14,
#    'H_quantum': 1.3809139430522919,
#    'H_classical': 0.8389222025871277,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 66.8},
#   '4': {'test_acc': 0.758,
#    'val_acc': 0.692,
#    'best_epoch': 17,
#    'H_quantum': 1.3686415255069733,
#    'H_classical': 0.6139421910047531,
#    'params': 95267,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 67.8}},
#  'C_classical_N1000': {'0': {'test_acc': 0.816,
#    'val_acc': 0.73,
#    'best_epoch': 7,
#    'H_quantum': nan,
#    'H_classical': 0.8725993484258652,
#    'params': 121606,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 7.8},
#   '1': {'test_acc': 0.79,
#    'val_acc': 0.71,
#    'best_epoch': 12,
#    'H_quantum': nan,
#    'H_classical': 1.0758181810379028,
#    'params': 121606,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 7.7},
#   '2': {'test_acc': 0.748,
#    'val_acc': 0.752,
#    'best_epoch': 13,
#    'H_quantum': nan,
#    'H_classical': 0.5890383124351501,
#    'params': 121606,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 7.7},
#   '3': {'test_acc': 0.782,
#    'val_acc': 0.728,
#    'best_epoch': 10,
#    'H_quantum': nan,
#    'H_classical': 0.8188373297452927,
#    'params': 121606,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 7.7},
#   '4': {'test_acc': 0.784,
#    'val_acc': 0.738,
#    'best_epoch': 14,
#    'H_quantum': nan,
#    'H_classical': 1.0803576409816742,
#    'params': 121606,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 7.7}},
#  'C_qnone_N1000': {'0': {'test_acc': 0.764,
#    'val_acc': 0.72,
#    'best_epoch': 15,
#    'H_quantum': 1.2804743945598602,
#    'H_classical': 1.1213428974151611,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 98.3},
#   '1': {'test_acc': 0.782,
#    'val_acc': 0.732,
#    'best_epoch': 18,
#    'H_quantum': 1.5321629643440247,
#    'H_classical': 0.6612728387117386,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 100.8},
#   '2': {'test_acc': 0.802,
#    'val_acc': 0.752,
#    'best_epoch': 15,
#    'H_quantum': 1.4052461981773376,
#    'H_classical': 1.0675796568393707,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 104.7},
#   '3': {'test_acc': 0.754,
#    'val_acc': 0.734,
#    'best_epoch': 9,
#    'H_quantum': 1.2005223035812378,
#    'H_classical': 1.2133552730083466,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 102.8},
#   '4': {'test_acc': 0.778,
#    'val_acc': 0.736,
#    'best_epoch': 12,
#    'H_quantum': 0.8477466255426407,
#    'H_classical': 0.9434884786605835,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 105.9}},
#  'C_qcross_N1000': {'0': {'test_acc': 0.808,
#    'val_acc': 0.722,
#    'best_epoch': 18,
#    'H_quantum': 1.279456466436386,
#    'H_classical': 1.1478796899318695,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 111.9},
#   '1': {'test_acc': 0.788,
#    'val_acc': 0.728,
#    'best_epoch': 15,
#    'H_quantum': 1.4145565032958984,
#    'H_classical': 0.6735720038414001,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 112.2},
#   '2': {'test_acc': 0.798,
#    'val_acc': 0.768,
#    'best_epoch': 14,
#    'H_quantum': 1.403274416923523,
#    'H_classical': 1.0174296349287033,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 107.9},
#   '3': {'test_acc': 0.746,
#    'val_acc': 0.744,
#    'best_epoch': 13,
#    'H_quantum': 1.2103988230228424,
#    'H_classical': 1.242199957370758,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 100.5},
#   '4': {'test_acc': 0.816,
#    'val_acc': 0.746,
#    'best_epoch': 15,
#    'H_quantum': 1.2495976388454437,
#    'H_classical': 1.039797306060791,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 106.5}},
#  'C_qfull_N1000': {'0': {'test_acc': 0.804,
#    'val_acc': 0.728,
#    'best_epoch': 15,
#    'H_quantum': 1.1910706460475922,
#    'H_classical': 1.1541665196418762,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 109.3},
#   '1': {'test_acc': 0.774,
#    'val_acc': 0.72,
#    'best_epoch': 18,
#    'H_quantum': 1.594467669725418,
#    'H_classical': 0.7121191769838333,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 105.6},
#   '2': {'test_acc': 0.79,
#    'val_acc': 0.742,
#    'best_epoch': 17,
#    'H_quantum': 1.4255474209785461,
#    'H_classical': 1.046082764863968,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 113.0},
#   '3': {'test_acc': 0.754,
#    'val_acc': 0.724,
#    'best_epoch': 12,
#    'H_quantum': 1.410617709159851,
#    'H_classical': 1.2289566695690155,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 113.3},
#   '4': {'test_acc': 0.778,
#    'val_acc': 0.728,
#    'best_epoch': 19,
#    'H_quantum': 1.2428005039691925,
#    'H_classical': 1.0578593313694,
#    'params': 121699,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 112.9}},
#  'C_classical_N2000': {'0': {'test_acc': 0.81,
#    'val_acc': 0.766,
#    'best_epoch': 8,
#    'H_quantum': nan,
#    'H_classical': 1.0365971624851227,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 14.2},
#   '1': {'test_acc': 0.832,
#    'val_acc': 0.764,
#    'best_epoch': 18,
#    'H_quantum': nan,
#    'H_classical': 0.6485866159200668,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 14.6},
#   '2': {'test_acc': 0.83,
#    'val_acc': 0.756,
#    'best_epoch': 16,
#    'H_quantum': nan,
#    'H_classical': 0.899865984916687,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 14.6},
#   '3': {'test_acc': 0.832,
#    'val_acc': 0.786,
#    'best_epoch': 9,
#    'H_quantum': nan,
#    'H_classical': 0.8139335215091705,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 14.6},
#   '4': {'test_acc': 0.814,
#    'val_acc': 0.758,
#    'best_epoch': 13,
#    'H_quantum': nan,
#    'H_classical': 0.9553664475679398,
#    'params': 168710,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 14.1}},
#  'C_qnone_N2000': {'0': {'test_acc': 0.822,
#    'val_acc': 0.766,
#    'best_epoch': 16,
#    'H_quantum': 1.669319599866867,
#    'H_classical': 0.8244677931070328,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 177.7},
#   '1': {'test_acc': 0.824,
#    'val_acc': 0.758,
#    'best_epoch': 10,
#    'H_quantum': 1.244344711303711,
#    'H_classical': 1.1960105001926422,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 168.3},
#   '2': {'test_acc': 0.816,
#    'val_acc': 0.76,
#    'best_epoch': 19,
#    'H_quantum': 1.131663292646408,
#    'H_classical': 0.8695641905069351,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 173.0},
#   '3': {'test_acc': 0.82,
#    'val_acc': 0.77,
#    'best_epoch': 11,
#    'H_quantum': 1.584077775478363,
#    'H_classical': 0.9725460261106491,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 163.9},
#   '4': {'test_acc': 0.806,
#    'val_acc': 0.742,
#    'best_epoch': 9,
#    'H_quantum': 1.5229251682758331,
#    'H_classical': 1.0069598257541656,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 178.4}},
#  'C_qcross_N2000': {'0': {'test_acc': 0.85,
#    'val_acc': 0.778,
#    'best_epoch': 20,
#    'H_quantum': 0.9479328840970993,
#    'H_classical': 0.7471499592065811,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 188.7},
#   '1': {'test_acc': 0.82,
#    'val_acc': 0.764,
#    'best_epoch': 17,
#    'H_quantum': 1.0898671746253967,
#    'H_classical': 1.005077749490738,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 182.3},
#   '2': {'test_acc': 0.83,
#    'val_acc': 0.746,
#    'best_epoch': 18,
#    'H_quantum': 0.6224619597196579,
#    'H_classical': 0.9002053141593933,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 193.2},
#   '3': {'test_acc': 0.836,
#    'val_acc': 0.784,
#    'best_epoch': 19,
#    'H_quantum': 1.6548664271831512,
#    'H_classical': 0.9883086532354355,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 190.8},
#   '4': {'test_acc': 0.814,
#    'val_acc': 0.756,
#    'best_epoch': 9,
#    'H_quantum': 1.408781886100769,
#    'H_classical': 0.9159607887268066,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 182.7}},
#  'C_qfull_N2000': {'0': {'test_acc': 0.834,
#    'val_acc': 0.77,
#    'best_epoch': 13,
#    'H_quantum': 1.4893090724945068,
#    'H_classical': 0.7814028114080429,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 186.2},
#   '1': {'test_acc': 0.818,
#    'val_acc': 0.758,
#    'best_epoch': 14,
#    'H_quantum': 1.073854148387909,
#    'H_classical': 1.050966054201126,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 194.9},
#   '2': {'test_acc': 0.81,
#    'val_acc': 0.75,
#    'best_epoch': 9,
#    'H_quantum': 0.8550937920808792,
#    'H_classical': 0.94832544028759,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 190.2},
#   '3': {'test_acc': 0.812,
#    'val_acc': 0.772,
#    'best_epoch': 11,
#    'H_quantum': 1.7232805490493774,
#    'H_classical': 1.00816011428833,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 191.9},
#   '4': {'test_acc': 0.804,
#    'val_acc': 0.748,
#    'best_epoch': 15,
#    'H_quantum': 1.3319888710975647,
#    'H_classical': 0.9485975950956345,
#    'params': 168803,
#    'n_qubits': 4,
#    'n_heads': 4,
#    'seconds': 188.4}}}

# %% [markdown]
# ## Experiment D — Qubit width / encoding bottleneck
# 2 / 4 / 8 qubits = 1 / 2 / 4 angles encoded per side. Tests whether widening the input encoding gives entanglement room to matter. **Memory note:** the statevector is 2^n_qubits per pair, so this cell uses a smaller batch and sequence length; n_qubits=8 is the slowest run in the notebook.

# %%
# Conservative settings keep n_qubits=8 within memory; classical is the reference.
# n_qubits=8 is the slowest cell in the whole study (statevector = 2^8 per pair),
# so this experiment uses a smaller subset, fewer epochs, and fewer seeds.
# The grid runs nq=2 and nq=4 first (cheap) and checkpoints, so you get those
# results before nq=8 starts — you can interrupt before nq=8 if short on time.
D_OVER  = dict(batch_size=16, max_len=min(MAX_LEN, 14), limit_train=800, epochs=12)
D_SEEDS = SEEDS[:3]                         # 3 seeds for the expensive sweep
gridD = [cfg("classical", "D_classical", **D_OVER)]
for nq in [2, 4, 8]:                        # nq=8 last (slowest)
    for c in ["qnone","qcross","qfull"]:
        gridD.append(cfg(c, f"D_{c}_nq{nq}", n_qubits=nq, **D_OVER))
run_experiment("expD_qubits", gridD, D_SEEDS)

# %% [markdown]
# ## Experiment E — Depth ablation (quantum head in the LAST block)
# Identical to Experiment A in every respect **except** the quantum head sits in
# block 1 (the final block; the model has 2 blocks) instead of block 0. This
# isolates *layer position* as the only variable: same single quantum head, same
# dose of entanglement, deeper features. Compare `E_*` against `A_*`.

# %%
gridE = [cfg(c, f"E_{c}", quantum_in_block=1) for c in
         ["classical","qnone","qintra","qcross","qfull"]]
run_experiment("expE_depth", gridE, SEEDS)

# %% [markdown]
# ## Reporting & figures
# Reads the Drive checkpoints, prints mean±std tables with permutation tests, and saves publication figures (PNG + PDF) to the Drive `figures/` folder. Safe to run with partial results.

# %%
import matplotlib
matplotlib.use("Agg"); import matplotlib.pyplot as plt
plt.rcParams.update({"font.size":11,"axes.spines.top":False,"axes.spines.right":False,
                     "axes.grid":True,"grid.alpha":0.25,"grid.linestyle":"--"})

def _accs(res, key):
    return [v["test_acc"] for v in res.get(key, {}).values()]

def _ms(xs):
    n=len(xs); mu=sum(xs)/n if n else float('nan')
    sd=(sum((x-mu)**2 for x in xs)/(n-1))**0.5 if n>1 else 0.0
    return mu,sd,n

def table(res, keys, title, pairs=None):
    print(f"\n=== {title} ===")
    print(f"{'key':16} {'mean':>8} {'std':>7} {'n':>3}  H_q     H_c")
    summ={}
    for k in keys:
        a=_accs(res,k)
        if not a: continue
        mu,sd,n=_ms(a); summ[k]=a
        runs=list(res[k].values())
        hq=sum(float(x['H_quantum']) if str(x['H_quantum'])!='nan' else float('nan') for x in runs)/len(runs)
        hc=sum(float(x['H_classical']) for x in runs)/len(runs)
        print(f"{k:16} {mu:8.4f} {sd:7.4f} {n:3d}  {hq:6.3f}  {hc:6.3f}")
    print(f"{'random':16} {1.0/N_CLASSES:8.4f}")
    if pairs:
        for x,y in pairs:
            if len(summ.get(x,[]))>1 and len(summ.get(y,[]))>1:
                _,p,mode=permutation_test(summ[x],summ[y])
                dm=sum(summ[x])/len(summ[x])-sum(summ[y])/len(summ[y])
                print(f"   {x} vs {y}: Δ={dm:+.4f} p={p:.4f} {'*' if p<0.05 else ''} [{mode}]")
    return summ

def bar(res, keys, labels, title, fname):
    ms=[_ms(_accs(res,k)) for k in keys]
    if not any(m[2] for m in ms): print("no data for",fname); return
    mu=[m[0] for m in ms]; sd=[m[1] for m in ms]
    cols=["#9aa0a6","#a8d0e6","#a8d0e6","#1b6ca8","#0a3d62"][:len(keys)]
    fig,ax=plt.subplots(figsize=(6.2,4.2)); x=range(len(keys))
    ax.bar(x,mu,yerr=sd,capsize=5,color=cols,edgecolor="black",linewidth=.6)
    ax.set_xticks(list(x)); ax.set_xticklabels(labels)
    ax.set_ylabel("test accuracy"); ax.set_title(title)
    lo=min(m-s for m,s in zip(mu,sd)); hi=max(m+s for m,s in zip(mu,sd))
    pad=(hi-lo)*.5+.005; ax.set_ylim(lo-pad,hi+pad*1.4)
    for xi,m in zip(x,mu): ax.text(xi,m,f"{m:.3f}",ha="center",va="bottom",fontsize=8)
    fig.tight_layout()
    for ext in ("png","pdf"): fig.savefig(os.path.join(FIG_DIR,f"{fname}.{ext}"),dpi=300,bbox_inches="tight")
    plt.close(fig); print("saved",fname)

def line_vs(res, xvals, key_fmt, conds, title, xlabel, fname):
    fig,ax=plt.subplots(figsize=(6.2,4.2))
    for c in conds:
        ys,es=[],[]
        for xv in xvals:
            mu,sd,n=_ms(_accs(res,key_fmt(c,xv))); ys.append(mu); es.append(sd)
        if any(y==y for y in ys):
            ax.errorbar(xvals,ys,yerr=es,marker="o",capsize=4,label=c)
    ax.set_xlabel(xlabel); ax.set_ylabel("test accuracy"); ax.set_title(title)
    ax.axhline(1.0/N_CLASSES,ls=":",color="#888",label="random")
    ax.legend(frameon=False,fontsize=9); fig.tight_layout()
    for ext in ("png","pdf"): fig.savefig(os.path.join(FIG_DIR,f"{fname}.{ext}"),dpi=300,bbox_inches="tight")
    plt.close(fig); print("saved",fname)

CONDS5=["classical","qnone","qintra","qcross","qfull"]
LAB5=["classical","q-none","q-intra","q-cross","q-full"]
ABL_PAIRS=[("{p}qfull","{p}classical"),("{p}qfull","{p}qnone"),
           ("{p}qcross","{p}qnone"),("{p}qfull","{p}qcross")]

# Experiment A
rA=_load(os.path.join(RESULTS_DIR,"expA_4head.json"))
if rA:
    table(rA,[f"A_{c}" for c in CONDS5],"A · 4-head ablation",
          [(x.format(p="A_"),y.format(p="A_")) for x,y in ABL_PAIRS])
    bar(rA,[f"A_{c}" for c in CONDS5],LAB5,f"{DATASET.upper()} · 4-head ablation","A_4head")

# Experiment B
rB=_load(os.path.join(RESULTS_DIR,"expB_1head.json"))
if rB:
    table(rB,[f"B_{c}" for c in CONDS5],"B · single-head ablation",
          [(x.format(p="B_"),y.format(p="B_")) for x,y in ABL_PAIRS])
    bar(rB,[f"B_{c}" for c in CONDS5],LAB5,f"{DATASET.upper()} · single head","B_1head")

# Experiment C
rC=_load(os.path.join(RESULTS_DIR,"expC_dataeff.json"))
if rC:
    table(rC,[f"C_{c}_N{N}" for N in N_EFF for c in ["classical","qnone","qcross","qfull"]],
          "C · data-efficiency")
    line_vs(rC,N_EFF,lambda c,N:f"C_{c}_N{N}",["classical","qnone","qcross","qfull"],
            f"{DATASET.upper()} · data efficiency","train size N","C_dataeff")

# Experiment D
rD=_load(os.path.join(RESULTS_DIR,"expD_qubits.json"))
if rD:
    table(rD,["D_classical"]+[f"D_{c}_nq{nq}" for nq in [2,4,8] for c in ["qnone","qcross","qfull"]],
          "D · qubit width")
    line_vs(rD,[2,4,8],lambda c,nq:f"D_{c}_nq{nq}",["qnone","qcross","qfull"],
            f"{DATASET.upper()} · qubit width","n_qubits","D_qubits")

print("\nAll figures saved to", FIG_DIR)

# %%
# Experiment E — depth ablation reporting
rE=_load(os.path.join(RESULTS_DIR,"expE_depth.json"))
if rE:
    table(rE,[f"E_{c}" for c in CONDS5],"E · quantum head in LAST block",
          [(x.format(p="E_"),y.format(p="E_")) for x,y in ABL_PAIRS])
    bar(rE,[f"E_{c}" for c in CONDS5],LAB5,f"{DATASET.upper()} · quantum in last block","E_depth")

# Cross-experiment: does layer position move accuracy?  (A = block 0, E = block 1)
rA_=_load(os.path.join(RESULTS_DIR,"expA_4head.json"))
if rA_ and rE:
    print("\n=== Layer-position effect: block 0 (A) vs block 1 (E) ===")
    for c in CONDS5:
        a=_accs(rA_,f"A_{c}"); e=_accs(rE,f"E_{c}")
        if len(a)>1 and len(e)>1:
            _,p,mode=permutation_test(a,e)
            d=sum(e)/len(e)-sum(a)/len(a)
            print(f"   {c:10} block1-block0 Δ={d:+.4f} p={p:.4f} {'*' if p<0.05 else ''} [{mode}]")
